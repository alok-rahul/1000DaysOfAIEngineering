# %% [markdown]
# ### Day 3 - Variables in Python

# %%
alok = 34
rahul =66
alokrahul = alok + rahul
print(alokrahul)
# Out:
# 100

# %% [markdown]
# ## Naming convention
# #### 1. Variables should start with a letter, underscore or should contain the letter
# #### 2. Variables are case sensative
# #### 3. Should be descriptive
# ####  4. Variables are case sensative

# %% [markdown]
# # Valid variable name

# %%
first_profit_share = '27 percent'

# %%
first_company = alok

# %%
second_company = rahul
